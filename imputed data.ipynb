# %%
import pandas as pd
import numpy as np
import networkx as nx
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
import pickle

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#         edge_id  length  minute      speed  is_holiday  weather
# 0           246    1726     505  22.140185           1        1
# 1           316    1750     740  54.303369           0        0
# 2           387    1612     745  56.303877           0        1
# 3           303    1927    1335  23.641228           0        2
# 4           250    1901     915  41.503161           0        1
# ...         ...     ...     ...        ...         ...      ...
# 784219      221    1851    1015  27.068770           0        1
# 784220      227    1768     175  47.168667           0        1
# 784221      110    1699    1220  28.605635           0        1
# 784222      289    1750    1410  21.889339           0        1
# 784223       83    1903     775  46.995337           0        1
#
# [784224 rows x 6 columns]

# %%
df['speed'].hist(bins=300)
# Out:
# <AxesSubplot:>

# %%
from sklearn.impute import KNNImputer
imp = KNNImputer(n_neighbors=5)
x=imp.fit_transform(df.sort_values(by='edge_id'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 from sklearn.impute import KNNImputer
#       2 imp = KNNImputer(n_neighbors=885)
# ----> 3 x=imp.fit_transform(df.sort_values(by='edge_id'))
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_knn.py:336, in KNNImputer.transform(self, X)
#     327 # process in fixed-memory chunks
#     328 gen = pairwise_distances_chunked(
#     329     X[row_missing_idx, :],
#     330     self._fit_X,
#    (...)
#     334     reduce_func=process_chunk,
#     335 )
# --> 336 for chunk in gen:
#     337     # process_chunk modifies X in place. No return value.
#     338     pass
#     340 return super()._concatenate_indicator(X[:, valid_mask], X_indicator)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1717, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1715 else:
#    1716     X_chunk = X[sl]
# -> 1717 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1718 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1719     metric, None
#    1720 ) is euclidean_distances:
#    1721     # zeroing diagonal, taking care of aliases of "euclidean",
#    1722     # i.e. "l2"
#    1723     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1889, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1886         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    1887     func = partial(distance.cdist, metric=metric, **kwds)
# -> 1889 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1430, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1427 X, Y, dtype = _return_float_dtype(X, Y)
#    1429 if effective_n_jobs(n_jobs) == 1:
# -> 1430     return func(X, Y, **kwds)
#    1432 # enforce a threading backend to prevent data communication overhead
#    1433 fd = delayed(_dist_wrapper)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:476, in nan_euclidean_distances(X, Y, squared, missing_values, copy)
#     474 XX = X * X
#     475 YY = Y * Y
# --> 476 distances -= np.dot(XX, missing_Y.T)
#     477 distances -= np.dot(missing_X, YY.T)
#     479 np.clip(distances, 0, None, out=distances)
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
x=pd.read_csv('data_imp.csv')

# %%
x
# Out:
#             0       1      2          3    4    5
# 0         0.0  1618.0  605.0  45.490138  1.0  1.0
# 1         0.0  1618.0  180.0  58.136208  0.0  0.0
# 2         0.0  1618.0  770.0  35.708970  0.0  0.0
# 3         0.0  1618.0  970.0  33.432919  0.0  0.0
# 4         0.0  1618.0  980.0  40.524331  0.0  0.0
# ...       ...     ...    ...        ...  ...  ...
# 784219  389.0  1920.0  770.0  50.024419  0.0  0.0
# 784220  389.0  1920.0  675.0  52.047795  0.0  0.0
# 784221  389.0  1920.0  110.0  50.552516  0.0  1.0
# 784222  389.0  1920.0  990.0  39.998259  0.0  0.0
# 784223  389.0  1920.0  650.0  52.857924  0.0  0.0
#
# [784224 rows x 6 columns]
